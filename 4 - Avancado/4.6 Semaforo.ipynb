# %% [markdown]
# #### Threading Semaforo
# ##### Se aplica a biblioteca multiprocessing também!
# ###### Observe que cada thread é executada de forma descontrolada

# %%
import cProfile
import time
import threading


def funcao_demorada(id_thread):
    print(f"Thread {id_thread} iniciada of func 1")
    time.sleep(2)
    print(f"Thread {id_thread} concluida of func 1")

def funcao_demorada2(id_thread):
    print(f"Thread {id_thread} iniciada of func 2")
    time.sleep(3)
    print(f"Thread {id_thread} concluida of func 2")

def main():
    theads = []
    for i in range(5):
        #funcao_demorada()
        #funcao_demorada2()
        thead1 = threading.Thread(target=funcao_demorada, args=(i, ))
        thead2 = threading.Thread(target=funcao_demorada2, args= (10+i,))

        thead1.start()
        thead2.start()

        theads.append(thead1)
        theads.append(thead2)

    for thead in theads:
        thead.join()
if __name__ == "__main__":
    #iniciando o profiler
    profiler = cProfile.Profile() #Cria o obejto baseado no profiler
    profiler.enable() #Habilita o Profiler

    #inica a função principal do software
    main()
    
    profiler.disable() 
    profiler.print_stats(sort='cumulative')
# Out:
# Thread 0 iniciada of func 1
# Thread 10 iniciada of func 2
# Thread 1 iniciada of func 1
# Thread 11 iniciada of func 2
# Thread 2 iniciada of func 1
# Thread 12 iniciada of func 2
# Thread 3 iniciada of func 1
# Thread 13 iniciada of func 2
# Thread 4 iniciada of func 1
# Thread 14 iniciada of func 2
# Thread 0 concluida of func 1
# Thread 1 concluida of func 1
# Thread 2 concluida of func 1
# Thread 3 concluida of func 1
# Thread 4 concluida of func 1
# Thread 10 concluida of func 2
# Thread 12 concluida of func 2
# Thread 11 concluida of func 2
# Thread 13 concluida of func 2
# Thread 14 concluida of func 2
#          3166 function calls (3060 primitive calls) in 3.009 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     15/11    0.000    0.000    9.010    0.819 threading.py:1153(_wait_for_tstate_lock)
#         8    0.003    0.000    7.389    0.924 base_events.py:1910(_run_once)
#         8    0.000    0.000    7.383    0.923 selectors.py:319(select)
#         8    0.000    0.000    7.383    0.923 selectors.py:313(_select)
#         8    0.382    0.048    7.383    0.923 {built-in method select.select}
#         9    0.000    0.000    6.007    0.667 threading.py:1115(join)
#      10/1    0.000    0.000    3.005    3.005 threading.py:1016(_bootstrap)
#      10/1    0.000    0.000    3.005    3.005 threading.py:1056(_bootstrap_inner)
#      10/1    0.000    0.000    3.005    3.005 ipkernel.py:744(run_closure)
#       5/1    0.000    0.000    2.001    2.001 3078168427.py:6(funcao_demorada)
#        20    0.000    0.000    0.004    0.000 {built-in method builtins.print}
#        40    0.000    0.000    0.004    0.000 iostream.py:655(write)
#         5    0.000    0.000    0.004    0.001 iostream.py:259(schedule)
#        40    0.000    0.000    0.003    0.000 iostream.py:577(_schedule_flush)
#         5    0.000    0.000    0.003    0.001 iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.003    0.002 context.py:326(socket)
#         2    0.003    0.001    0.003    0.002 socket.py:128(__init__)
#         2    0.003    0.001    0.003    0.001 {method '__exit__' of 'sqlite3.Connection' objects}
#        10    0.000    0.000    0.003    0.000 threading.py:973(start)
#        10    0.000    0.000    0.003    0.000 threading.py:637(wait)
#        10    0.000    0.000    0.002    0.000 threading.py:323(wait)
#         9    0.000    0.000    0.002    0.000 events.py:86(_run)
#         9    0.000    0.000    0.002    0.000 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.001    0.000 asyncio.py:200(_handle_events)
#         5    0.000    0.000    0.001    0.000 zmqstream.py:584(_handle_events)
#         4    0.000    0.000    0.001    0.000 ioloop.py:742(_run_callback)
#         4    0.000    0.000    0.001    0.000 iostream.py:616(_flush)
#         2    0.000    0.000    0.001    0.000 session.py:754(send)
#         5    0.000    0.000    0.001    0.000 zmqstream.py:625(_handle_recv)
#        10    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#      10/1    0.000    0.000    0.000    0.000 threading.py:999(run)
#       5/1    0.000    0.000    0.000    0.000 3078168427.py:11(funcao_demorada2)
#      10/1    2.610    0.261    0.000    0.000 {built-in method time.sleep}
#         2    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:557(_run_callback)
#         5    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#        11    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#        19    0.000    0.000    0.000    0.000 socket.py:626(send)
#         8    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#        40    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        10    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:664(_rebuild_io_state)
#         8    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#        10    0.000    0.000    0.000    0.000 threading.py:882(__init__)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#     77/40    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        11    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         8    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#         2    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#         4    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#        10    0.000    0.000    0.000    0.000 threading.py:1043(_set_tstate_lock)
#         5    0.000    0.000    0.000    0.000 socket.py:778(recv_multipart)
#        10    0.000    0.000    0.000    0.000 threading.py:616(set)
#   333/321    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         6    0.000    0.000    0.000    0.000 zmqstream.py:687(_update_handler)
#         8    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#         4    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        17    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#         2    0.000    0.000    0.000    0.000 session.py:649(msg)
#         2    0.000    0.000    0.000    0.000 session.py:675(sign)
#        32    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         6    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#        10    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         6    0.000    0.000    0.000    0.000 socket.py:367(__setattr__)
#         3    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         2    0.000    0.000    0.000    0.000 socket.py:317(connect)
#         5    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#        18    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#       105    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#         3    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#        57    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#        10    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         3    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#         2    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        20    0.000    0.000    0.000    0.000 threading.py:855(_maintain_shutdown_locks)
#        32    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         6    0.000    0.000    0.000    0.000 attrsettr.py:17(__setattr__)
#        15    0.000    0.000    0.000    0.000 typing.py:392(inner)
#        10    0.000    0.000    0.000    0.000 threading.py:588(__init__)
#        10    0.000    0.000    0.000    0.000 threading.py:1079(_stop)
#         3    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         6    0.000    0.000    0.000    0.000 typing.py:1212(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        62    0.000    0.000    0.000    0.000 threading.py:1483(current_thread)
#        31    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#        40    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        21    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         6    0.000    0.000    0.000    0.000 typing.py:1483(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:543(sending)
#        54    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        40    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         4    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         2    0.000    0.000    0.000    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         4    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        57    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         2    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#        20    0.000    0.000    0.000    0.000 base_events.py:734(time)
#        10    0.000    0.000    0.000    0.000 threading.py:277(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         5    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#         6    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         4    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         8    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         3    0.000    0.000    0.000    0.000 events.py:111(__init__)
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        97    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        75    0.000    0.000    0.000    0.000 threading.py:1196(ident)
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#         3    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        21    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#        10    0.000    0.000    0.000    0.000 typing.py:1276(__hash__)
#        92    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        21    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1885(trait_defaults)
#         2    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        75    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#        20    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         6    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#        48    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         8    0.000    0.000    0.000    0.000 hmac.py:117(update)
#        46    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:837(_newname)
#         2    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:1036(_set_ident)
#        10    0.000    0.000    0.000    0.000 threading.py:1106(_delete)
#       110    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        50    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        30    0.000    0.000    0.000    0.000 threading.py:1234(daemon)
#        25    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        10    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#        10    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'difference_update' of 'set' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         2    0.000    0.000    0.000    0.000 {built-in method now}
#         2    0.000    0.000    0.000    0.000 attrsettr.py:39(_set_attr_opt)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         1    0.000    0.000    0.000    0.000 traitlets.py:591(default)
#        22    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         7    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#        21    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:1354(_make_invoke_excepthook)
#         2    0.000    0.000    0.000    0.000 context.py:281(_add_socket)
#        21    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         6    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:2331(make_dynamic_default)
#        10    0.000    0.000    0.000    0.000 threading.py:1040(_set_native_id)
#         1    0.000    0.000    0.000    0.000 threading.py:1533(enumerate)
#        11    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        93    0.000    0.000    0.000    0.000 typing.py:2173(cast)
#         2    0.000    0.000    0.000    0.000 socket.py:261(_connect_cm)
#         5    0.000    0.000    0.000    0.000 base_events.py:1895(_add_callback)
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         6    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#        13    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         8    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        14    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         5    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 enum.py:202(__get__)
#        25    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        12    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1873(_get_trait_default_generator)
#         8    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        11    0.000    0.000    0.000    0.000 zmqstream.py:539(receiving)
#         8    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        10    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         6    0.000    0.000    0.000    0.000 {built-in method time.time}
#         3    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 socket.py:54(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFDF0E47A20}
#         2    0.000    0.000    0.000    0.000 enum.py:1287(name)
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1824(has_trait)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         3    0.000    0.000    0.000    0.000 base_events.py:2005(get_debug)

# %% [markdown]
# #### Com Semaforo
# ###### DEmora mais a execução das threads, contudo é mais controlado

# %%
import cProfile
import time
import threading

semaforo = threading.Semaphore(2) #inicando semaforo

def funcao_demorada(id_thread):
    with semaforo:
        print(f"Thread {id_thread} iniciada of func 1")
        time.sleep(2)
        print(f"Thread {id_thread} concluida of func 1")

def funcao_demorada2(id_thread):
    with semaforo:
        print(f"Thread {id_thread} iniciada of func 2")
        time.sleep(3)
        print(f"Thread {id_thread} concluida of func 2")

def main():
    theads = []
    for i in range(5):
        #funcao_demorada()
        #funcao_demorada2()
        thead1 = threading.Thread(target=funcao_demorada, args=(i, ))
        thead2 = threading.Thread(target=funcao_demorada2, args= (10+i,))

        thead1.start()
        thead2.start()

        theads.append(thead1)
        theads.append(thead2)

    for thead in theads:
        thead.join()
if __name__ == "__main__":
    #iniciando o profiler
    profiler = cProfile.Profile() #Cria o obejto baseado no profiler
    profiler.enable() #Habilita o Profiler

    #inica a função principal do software
    main()
    
    profiler.disable() 
    profiler.print_stats(sort='cumulative')
# Out:
# Thread 0 iniciada of func 1
# Thread 10 iniciada of func 2
# Thread 0 concluida of func 1
# Thread 1 iniciada of func 1
# Thread 10 concluida of func 2
# Thread 11 iniciada of func 2
# Thread 1 concluida of func 1
# Thread 2 iniciada of func 1
# Thread 11 concluida of func 2
# Thread 12 iniciada of func 2
# Thread 2 concluida of func 1
# Thread 3 iniciada of func 1
# Thread 3 concluida of func 1
# Thread 13 iniciada of func 2
# Thread 12 concluida of func 2
# Thread 4 iniciada of func 1
# Thread 4 concluida of func 1
# Thread 14 iniciada of func 2
# Thread 13 concluida of func 2
# Thread 14 concluida of func 2
#          7158 function calls (6905 primitive calls) in 14.016 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        28    0.001    0.000   99.267    3.545 base_events.py:1910(_run_once)
#        28    0.000    0.000   79.242    2.830 selectors.py:319(select)
#        28    0.000    0.000   56.228    2.008 selectors.py:313(_select)
#        28    2.189    0.078   56.226    2.008 {built-in method select.select}
#        10    0.000    0.000   26.020    2.602 threading.py:1115(join)
#     30/11    0.002    0.000   20.017    1.820 threading.py:1153(_wait_for_tstate_lock)
#      10/1    0.001    0.000   14.014   14.014 threading.py:1016(_bootstrap)
#      10/1    0.000    0.000   14.014   14.014 threading.py:1056(_bootstrap_inner)
#      10/1    0.000    0.000    2.792    2.792 ipkernel.py:744(run_closure)
#      10/1    0.000    0.000    2.792    2.792 threading.py:999(run)
#       5/1    0.000    0.000    2.792    2.792 3263484402.py:13(funcao_demorada2)
#      10/1   11.798    1.180    2.790    2.790 {built-in method time.sleep}
#       5/1    0.000    0.000    1.789    1.789 3263484402.py:7(funcao_demorada)
#        20    0.000    0.000    0.014    0.001 {built-in method builtins.print}
#        17    0.000    0.000    0.012    0.001 iostream.py:138(_event_pipe)
#        40    0.001    0.000    0.012    0.000 iostream.py:655(write)
#         8    0.000    0.000    0.011    0.001 context.py:326(socket)
#         8    0.011    0.001    0.011    0.001 socket.py:128(__init__)
#        17    0.000    0.000    0.011    0.001 iostream.py:259(schedule)
#        40    0.000    0.000    0.011    0.000 iostream.py:577(_schedule_flush)
#        29    0.000    0.000    0.007    0.000 events.py:86(_run)
#        29    0.000    0.000    0.007    0.000 {method 'run' of '_contextvars.Context' objects}
#        19    0.000    0.000    0.004    0.000 asyncio.py:200(_handle_events)
#        19    0.000    0.000    0.004    0.000 zmqstream.py:584(_handle_events)
#         8    0.000    0.000    0.003    0.000 ioloop.py:742(_run_callback)
#         8    0.000    0.000    0.003    0.000 iostream.py:616(_flush)
#         8    0.000    0.000    0.002    0.000 session.py:754(send)
#        17    0.000    0.000    0.002    0.000 zmqstream.py:625(_handle_recv)
#        17    0.000    0.000    0.001    0.000 zmqstream.py:557(_run_callback)
#         8    0.000    0.000    0.001    0.000 session.py:690(serialize)
#        38    0.000    0.000    0.001    0.000 attrsettr.py:43(__getattr__)
#        17    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#        38    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#        32    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#        32    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#        73    0.001    0.000    0.001    0.000 socket.py:626(send)
#         8    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#         8    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#        19    0.000    0.000    0.001    0.000 zmqstream.py:664(_rebuild_io_state)
#         8    0.000    0.000    0.001    0.000 socket.py:703(send_multipart)
#        10    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#        32    0.000    0.000    0.001    0.000 encoder.py:183(encode)
#        32    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#        17    0.000    0.000    0.000    0.000 socket.py:778(recv_multipart)
#        24    0.000    0.000    0.000    0.000 socket.py:367(__setattr__)
#         8    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#   985/951    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        57    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#        19    0.000    0.000    0.000    0.000 zmqstream.py:687(_update_handler)
#        10    0.000    0.000    0.000    0.000 threading.py:973(start)
#         9    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#        40    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        10    0.000    0.000    0.000    0.000 threading.py:637(wait)
#        10    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         8    0.000    0.000    0.000    0.000 session.py:649(msg)
#         9    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#        67    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#       372    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#        10    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         9    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#        24    0.000    0.000    0.000    0.000 attrsettr.py:17(__setattr__)
#         8    0.000    0.000    0.000    0.000 socket.py:317(connect)
#         8    0.000    0.000    0.000    0.000 session.py:675(sign)
#       203    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#       122    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        10    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#        16    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#        10    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#        10    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         8    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#        16    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#        10    0.000    0.000    0.000    0.000 threading.py:882(__init__)
#        51    0.000    0.000    0.000    0.000 typing.py:392(inner)
#        10    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#        10    0.000    0.000    0.000    0.000 threading.py:528(__exit__)
#        20    0.000    0.000    0.000    0.000 threading.py:394(notify)
#        17    0.000    0.000    0.000    0.000 typing.py:1212(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:515(release)
#        10    0.000    0.000    0.000    0.000 threading.py:1043(_set_tstate_lock)
#        10    0.000    0.000    0.000    0.000 threading.py:616(set)
#        24    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#        10    0.000    0.000    0.000    0.000 threading.py:1079(_stop)
#        16    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        17    0.000    0.000    0.000    0.000 typing.py:1483(__subclasscheck__)
#        90    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       122    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#       203    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#         8    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        10    0.000    0.000    0.000    0.000 events.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#        20    0.000    0.000    0.000    0.000 threading.py:855(_maintain_shutdown_locks)
#        97    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        29    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#      18/2    0.000    0.000    0.000    0.000 threading.py:323(wait)
#        10    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#        67    0.000    0.000    0.000    0.000 base_events.py:734(time)
#         8    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        47    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#        19    0.000    0.000    0.000    0.000 zmqstream.py:543(sending)
#        10    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        68    0.000    0.000    0.000    0.000 threading.py:1483(current_thread)
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        11    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         8    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#        74    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         8    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        19    0.000    0.000    0.000    0.000 queue.py:97(empty)
#        10    0.000    0.000    0.000    0.000 threading.py:588(__init__)
#        40    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        40    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        29    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         8    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#      10/3    0.000    0.000    0.000    0.000 threading.py:468(acquire)
#       202    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        34    0.000    0.000    0.000    0.000 typing.py:1276(__hash__)
#         4    0.000    0.000    0.000    0.000 socket.py:236(close)
#         1    0.000    0.000    0.000    0.000 3263484402.py:19(main)
#        17    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         8    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         8    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         2    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         1    0.000    0.000    0.000    0.000 futures.py:311(_set_result_unless_cancelled)
#    134/10    0.001    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        18    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#        40    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        65    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        40    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#        41    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         8    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#        32    0.000    0.000    0.000    0.000 hmac.py:117(update)
#        39    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         8    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         8    0.000    0.000    0.000    0.000 attrsettr.py:39(_set_attr_opt)
#        72    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         8    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#        67    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         8    0.000    0.000    0.000    0.000 context.py:281(_add_socket)
#        24    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method now}
#        17    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        57    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        98    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        10    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#         8    0.000    0.000    0.000    0.000 socket.py:261(_connect_cm)
#        90    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        18    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:277(__init__)
#       303    0.000    0.000    0.000    0.000 typing.py:2173(cast)
#        60    0.000    0.000    0.000    0.000 threading.py:1196(ident)
#        10    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#        32    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        78    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        19    0.000    0.000    0.000    0.000 base_events.py:1895(_add_callback)
#         9    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#        53    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#        18    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#         4    0.000    0.000    0.000    0.000 context.py:285(_rm_socket)
#        46    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:785(call_soon)
#        41    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:1106(_delete)
#       128    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        46    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:837(_newname)
#        16    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        28    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        19    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        32    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'difference_update' of 'set' objects}
#        30    0.000    0.000    0.000    0.000 threading.py:1234(daemon)
#        10    0.000    0.000    0.000    0.000 threading.py:1036(_set_ident)
#        24    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        19    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         8    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 base_events.py:814(_call_soon)
#         8    0.000    0.000    0.000    0.000 enum.py:202(__get__)
#        16    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         8    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 _weakrefset.py:115(discard)
#        19    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#        10    0.000    0.000    0.000    0.000 threading.py:1354(_make_invoke_excepthook)
#        34    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         8    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        36    0.000    0.000    0.000    0.000 zmqstream.py:539(receiving)
#        32    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method time.time}
#        40    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 events.py:155(cancel)
#        20    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#        10    0.000    0.000    0.000    0.000 threading.py:1040(_set_native_id)
#         9    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         8    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         8    0.000    0.000    0.000    0.000 socket.py:54(__init__)
#        18    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         8    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFDF0E47A20}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         8    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         1    0.000    0.000    0.000    0.000 base_events.py:447(create_future)
#         8    0.000    0.000    0.000    0.000 enum.py:1287(name)
#        18    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         4    0.000    0.000    0.000    0.000 socket.py:175(__del__)
#        11    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#        13    0.000    0.000    0.000    0.000 base_events.py:2005(get_debug)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         8    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         8    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 base_events.py:1905(_timer_handle_cancelled)

# %% [markdown]
# #### Um semaforo para cada funcao

# %%
import cProfile
import time
import threading

semaforo_func1 = threading.Semaphore(1) #inicando semaforo
semaforo_func2 = threading.Semaphore(1) #inicando semaforo

def funcao_demorada(id_thread):
    with semaforo_func1:
        print(f"Thread {id_thread} iniciada of func 1")
        time.sleep(2)
        print(f"Thread {id_thread} concluida of func 1")

def funcao_demorada2(id_thread):
    with semaforo_func2:
        print(f"Thread {id_thread} iniciada of func 2")
        time.sleep(3)
        print(f"Thread {id_thread} concluida of func 2")

def main():
    theads = []
    for i in range(5):
        #funcao_demorada()
        #funcao_demorada2()
        thead1 = threading.Thread(target=funcao_demorada, args=(i, ))
        thead2 = threading.Thread(target=funcao_demorada2, args= (10+i,))

        thead1.start()
        thead2.start()

        theads.append(thead1)
        theads.append(thead2)

    for thead in theads:
        thead.join()
if __name__ == "__main__":
    #iniciando o profiler
    profiler = cProfile.Profile() #Cria o obejto baseado no profiler
    profiler.enable() #Habilita o Profiler

    #inica a função principal do software
    main()
    
    profiler.disable() 
    profiler.print_stats(sort='cumulative')
# Out:
# Thread 0 iniciada of func 1
# Thread 10 iniciada of func 2
# Thread 0 concluida of func 1
# Thread 1 iniciada of func 1
# Thread 10 concluida of func 2
# Thread 11 iniciada of func 2
# Thread 1 concluida of func 1
# Thread 2 iniciada of func 1
# Thread 2 concluida of func 1
# Thread 3 iniciada of func 1
# Thread 11 concluida of func 2
# Thread 12 iniciada of func 2
# Thread 3 concluida of func 1
# Thread 4 iniciada of func 1
# Thread 12 concluida of func 2
# Thread 13 iniciada of func 2
# Thread 4 concluida of func 1
# Thread 13 concluida of func 2
# Thread 14 iniciada of func 2
# Thread 14 concluida of func 2
#          8214 function calls (7945 primitive calls) in 15.016 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        36    0.001    0.000   91.283    2.536 base_events.py:1910(_run_once)
#        36    0.000    0.000   91.273    2.535 selectors.py:319(select)
#        37    0.000    0.000   80.270    2.169 selectors.py:313(_select)
#        37    5.207    0.141   62.251    1.682 {built-in method select.select}
#        10    0.000    0.000   18.015    1.802 threading.py:1115(join)
#     35/11    0.000    0.000   18.015    1.638 threading.py:1153(_wait_for_tstate_lock)
#      10/1    0.001    0.000   15.015   15.015 threading.py:1016(_bootstrap)
#      10/1    0.000    0.000   15.015   15.015 threading.py:1056(_bootstrap_inner)
#      10/2    9.778    0.978    1.905    0.953 {built-in method time.sleep}
#       5/1    0.000    0.000    0.796    0.796 1719374059.py:8(funcao_demorada)
#      10/1    0.000    0.000    0.109    0.109 ipkernel.py:744(run_closure)
#      10/1    0.000    0.000    0.109    0.109 threading.py:999(run)
#       5/1    0.000    0.000    0.109    0.109 1719374059.py:14(funcao_demorada2)
#        20    0.000    0.000    0.016    0.001 {built-in method builtins.print}
#        40    0.001    0.000    0.016    0.000 iostream.py:655(write)
#        19    0.000    0.000    0.015    0.001 iostream.py:259(schedule)
#        40    0.000    0.000    0.015    0.000 iostream.py:577(_schedule_flush)
#        19    0.000    0.000    0.014    0.001 iostream.py:138(_event_pipe)
#         9    0.000    0.000    0.014    0.002 context.py:326(socket)
#         9    0.013    0.001    0.013    0.001 socket.py:128(__init__)
#        37    0.000    0.000    0.009    0.000 events.py:86(_run)
#        37    0.000    0.000    0.009    0.000 {method 'run' of '_contextvars.Context' objects}
#        24    0.000    0.000    0.005    0.000 asyncio.py:200(_handle_events)
#        24    0.000    0.000    0.004    0.000 zmqstream.py:584(_handle_events)
#         9    0.000    0.000    0.004    0.000 ioloop.py:742(_run_callback)
#         9    0.000    0.000    0.003    0.000 iostream.py:616(_flush)
#         9    0.000    0.000    0.002    0.000 session.py:754(send)
#        19    0.000    0.000    0.002    0.000 zmqstream.py:625(_handle_recv)
#        19    0.000    0.000    0.002    0.000 zmqstream.py:557(_run_callback)
#         9    0.000    0.000    0.001    0.000 session.py:690(serialize)
#        49    0.000    0.000    0.001    0.000 attrsettr.py:43(__getattr__)
#        19    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#        36    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#        25    0.000    0.000    0.001    0.000 zmqstream.py:664(_rebuild_io_state)
#        49    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#        36    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#        82    0.001    0.000    0.001    0.000 socket.py:626(send)
#         9    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#         9    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#         9    0.000    0.000    0.001    0.000 socket.py:703(send_multipart)
#        36    0.000    0.000    0.001    0.000 encoder.py:183(encode)
#        19    0.000    0.000    0.001    0.000 socket.py:778(recv_multipart)
#        27    0.000    0.000    0.001    0.000 socket.py:367(__setattr__)
#        74    0.000    0.000    0.001    0.000 enum.py:1562(__and__)
#        40    0.000    0.000    0.001    0.000 iostream.py:505(parent_header)
#        25    0.000    0.000    0.001    0.000 zmqstream.py:687(_update_handler)
#        36    0.000    0.000    0.001    0.000 encoder.py:205(iterencode)
# 1176/1136    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         9    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#        10    0.000    0.000    0.000    0.000 threading.py:973(start)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        10    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#        10    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#         9    0.000    0.000    0.000    0.000 session.py:649(msg)
#        11    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#       459    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#        79    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#        27    0.000    0.000    0.000    0.000 attrsettr.py:17(__setattr__)
#         9    0.000    0.000    0.000    0.000 socket.py:317(connect)
#        10    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#       248    0.000    0.000    0.000    0.000 enum.py:726(__call__)
#        11    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         9    0.000    0.000    0.000    0.000 session.py:675(sign)
#         2    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#        12    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#      10/9    0.000    0.000    0.000    0.000 threading.py:637(wait)
#        18    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#        11    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         9    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#        57    0.000    0.000    0.000    0.000 typing.py:392(inner)
#        12    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#        18    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#       137    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        20    0.000    0.000    0.000    0.000 typing.py:1212(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#        10    0.000    0.000    0.000    0.000 threading.py:528(__exit__)
#        10    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#        20    0.000    0.000    0.000    0.000 threading.py:394(notify)
#        10    0.000    0.000    0.000    0.000 threading.py:515(release)
#        20    0.000    0.000    0.000    0.000 typing.py:1483(__subclasscheck__)
#        10    0.000    0.000    0.000    0.000 threading.py:882(__init__)
#        33    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#       111    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        18    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        12    0.000    0.000    0.000    0.000 events.py:111(__init__)
#       248    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#        10    0.000    0.000    0.000    0.000 threading.py:1079(_stop)
#         9    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        10    0.000    0.000    0.000    0.000 threading.py:1043(_set_tstate_lock)
#        10    0.000    0.000    0.000    0.000 threading.py:616(set)
#        37    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#        25    0.000    0.000    0.000    0.000 zmqstream.py:543(sending)
#        85    0.000    0.000    0.000    0.000 base_events.py:734(time)
#       137    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         9    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         8    0.000    0.000    0.000    0.000 socket.py:236(close)
#        47    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        14    0.000    0.000    0.000    0.000 events.py:36(__init__)
#        49    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        20    0.000    0.000    0.000    0.000 threading.py:855(_maintain_shutdown_locks)
#        93    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         9    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         9    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#         9    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#        25    0.000    0.000    0.000    0.000 queue.py:97(empty)
#        10    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#       111    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        69    0.000    0.000    0.000    0.000 threading.py:1483(current_thread)
#         4    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#      18/2    0.000    0.000    0.000    0.000 threading.py:323(wait)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        38    0.000    0.000    0.000    0.000 typing.py:1276(__hash__)
#        11    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        40    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        40    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        20    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         9    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         9    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#       234    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         9    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         2    0.000    0.000    0.000    0.000 futures.py:311(_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 1719374059.py:20(main)
#         9    0.000    0.000    0.000    0.000 context.py:281(_add_socket)
#         9    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#        19    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#        10    0.000    0.000    0.000    0.000 threading.py:588(__init__)
#        45    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        36    0.000    0.000    0.000    0.000 hmac.py:117(update)
#        29    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         9    0.000    0.000    0.000    0.000 attrsettr.py:39(_set_attr_opt)
#        85    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        20    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        75    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        76    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        40    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#    139/10    0.001    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#      10/3    0.000    0.000    0.000    0.000 threading.py:468(acquire)
#         9    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         8    0.000    0.000    0.000    0.000 context.py:285(_rm_socket)
#        41    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#        27    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#        39    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         9    0.000    0.000    0.000    0.000 socket.py:261(_connect_cm)
#         9    0.000    0.000    0.000    0.000 {built-in method now}
#        60    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        36    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        12    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#        99    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        24    0.000    0.000    0.000    0.000 base_events.py:1895(_add_callback)
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        60    0.000    0.000    0.000    0.000 threading.py:1196(ident)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        98    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        18    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#        36    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#       339    0.000    0.000    0.000    0.000 typing.py:2173(cast)
#        58    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#        61    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        79    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        25    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#        11    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         2    0.000    0.000    0.000    0.000 base_events.py:785(call_soon)
#         9    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:115(discard)
#        10    0.000    0.000    0.000    0.000 threading.py:277(__init__)
#        56    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:1106(_delete)
#        18    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 enum.py:202(__get__)
#        36    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#        24    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#        27    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        29    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       127    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#        18    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         2    0.000    0.000    0.000    0.000 events.py:155(cancel)
#         2    0.000    0.000    0.000    0.000 base_events.py:814(_call_soon)
#         9    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#        10    0.000    0.000    0.000    0.000 threading.py:837(_newname)
#        20    0.000    0.000    0.000    0.000 {method 'difference_update' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        41    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        44    0.000    0.000    0.000    0.000 zmqstream.py:539(receiving)
#        30    0.000    0.000    0.000    0.000 threading.py:1234(daemon)
#        10    0.000    0.000    0.000    0.000 threading.py:1036(_set_ident)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#        36    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method time.time}
#        38    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         9    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        12    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        45    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         9    0.000    0.000    0.000    0.000 socket.py:54(__init__)
#        17    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        19    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 base_events.py:447(create_future)
#        10    0.000    0.000    0.000    0.000 threading.py:1354(_make_invoke_excepthook)
#        10    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#        22    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#        10    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         9    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFDF0E47A20}
#         9    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         9    0.000    0.000    0.000    0.000 enum.py:1287(name)
#         9    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        10    0.000    0.000    0.000    0.000 threading.py:1040(_set_native_id)
#        20    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 socket.py:175(__del__)
#         9    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#        14    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#        18    0.000    0.000    0.000    0.000 base_events.py:2005(get_debug)
#         2    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         9    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         9    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 base_events.py:1905(_timer_handle_cancelled)
