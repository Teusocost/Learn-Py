# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import array

meu_array = array.array('i',[1,2,3])
print(meu_array)

# %%
for n in meu_array:
    print(n)

# %%
meu_array.append(20)
print(meu_array)

# %% [markdown]
# #### Array Float (cuidado com o lixo)

# %%
import array
meu_aray_float = array.array('f',[1.1,2.2,3.3])
print(meu_aray_float)
# Out:
# array('f', [1.100000023841858, 2.200000047683716, 3.299999952316284])
